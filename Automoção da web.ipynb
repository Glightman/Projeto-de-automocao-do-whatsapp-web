# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pyautogui as pag
import time as tm
import pyperclip as pc

navegador = webdriver.Chrome()

# %%
navegador.get('https://web.whatsapp.com/')
pag.click(499,28, clicks=2)
tm.sleep(20)
navegador.find_element_by_xpath('//*[@id="side"]/header/div[2]/div/span/div[3]/div/span').click()
navegador.find_element_by_xpath('//*[@id="side"]/header/div[2]/div/span/div[3]/span/div[1]/ul/li[1]/div[1]').click()
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[1]/span/div[1]/span/div[1]/div/div[1]/div/div/input').send_keys("meu amor")
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[1]/span/div[1]/span/div[1]/div/div[2]/div[1]/div/div/div/div/div/div[2]').click()
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[1]/span/div[1]/span/div[1]/div/span/div/span').click()
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[1]/span/div[1]/span/div[1]/div/div[2]/div/div[2]/div/div[2]').send_keys('TESTE DE AUTOMAÇÃO')
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[1]/span/div[1]/span/div[1]/div/div[1]/div/div/span/div/div[1]/span').click()
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/span[4]/div/ul/div/li[2]/div[1]').click()
tm.sleep(3)
pag.click(356,49)
tm.sleep(1)
pag.write(r'C:\Users\gabri\OneDrive\Imagens\Screenshots')
pag.press('enter')
tm.sleep(2)
pag.click(244,177, clicks=2)
tm.sleep(3)
pag.dragTo(660,389)
pag.scroll(100)
pag.scroll(100)
pag.scroll(100)
pag.scroll(100)
pag.scroll(100)
pag.scroll(100)
#confirmar
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/span[2]/div[1]/div/div/div/div/div/span/div[1]/div/div[2]/span/div/div/span').click()
#confirmar criação de grupo
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[1]/span/div[1]/span/div[1]/div/span/div/div/span').click()
tm.sleep(3)
#mudar descrição do grupo
navegador.find_element_by_xpath('//*[@id="main"]/header').click()
tm.sleep(1)
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/div/section/div[2]/div[2]/div/div/span[2]/div/span').click()
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/div/section/div[2]/div[2]/div/div[1]/div/div[2]').send_keys('ESTE GRUPO FOI CRIADO COM O OBJETIVO DE FAZER UM TESTE DE AUTOMOÇÃO!!!')
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/div/section/div[2]/div[2]/div/div[1]/span[2]/div/span').click()
#entrar nas configurações de grupo
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/div/section/div[4]/div[4]/div/div[1]/span').click()
#editar dados do grupo
tm.sleep(1)
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/div/div[1]/div/div/div/div[1]/span').click()
tm.sleep(1)
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/span[2]/div[1]/div/div/div/div/div/div[2]/form/ol/li[2]/label/input').click()
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/span[2]/div[1]/div/div/div/div/div/div[3]/div[2]/div/div').click()
#enviar mensagens
tm.sleep(1)
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/div/div[3]/div/div/div/div[1]/span').click()
tm.sleep(1)
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/span[2]/div[1]/div/div/div/div/div/div[2]/form/ol/li[2]/label/input').click()
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/span[2]/div[1]/div/div/div/div/div/div[3]/div[2]/div/div').click()
#permitir outro admin
tm.sleep(1)
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/div/div[4]/div/div/div/div/span').click()
tm.sleep(1)
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/span[2]/div[1]/div/div/div/div/div/div/div[2]/div[1]/div/div/div[2]/div/div[2]/div/div[2]/div[1]/div/span/span').click()
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/span[2]/div[1]/div/div/div/div/div/div/span[2]/div/div/div/span').click()
#copiar convite via link
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/header/div/div[1]/button/span').click()
tm.sleep(1)
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/div/section/div[5]/div[3]/div[2]/div/div').click()
tm.sleep(1)
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/div/div[4]/div[2]/div/span').click()

#grupo 2
tm.sleep(3)
navegador.find_element_by_xpath('//*[@id="side"]/header/div[2]/div/span/div[3]/div/span').click()
navegador.find_element_by_xpath('//*[@id="side"]/header/div[2]/div/span/div[3]/span/div[1]/ul/li[1]/div[1]').click()
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[1]/span/div[1]/span/div[1]/div/div[1]/div/div/input').send_keys("meu amor")
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[1]/span/div[1]/span/div[1]/div/div[2]/div[1]/div/div/div/div/div/div[2]').click()
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[1]/span/div[1]/span/div[1]/div/span/div/span').click()
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[1]/span/div[1]/span/div[1]/div/div[2]/div/div[2]/div/div[2]').send_keys('TESTE DE AUTOMAÇÃO')
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[1]/span/div[1]/span/div[1]/div/div[1]/div/div/span/div/div[1]/span').click()
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/span[4]/div/ul/div/li[2]/div[1]').click()
tm.sleep(3)
pag.click(356,49)
tm.sleep(1)
pag.write(r'C:\Users\gabri\OneDrive\Imagens\Screenshots')
pag.press('enter')
tm.sleep(2)
pag.click(244,177, clicks=2)
tm.sleep(3)
pag.dragTo(660,389)
pag.scroll(100)
pag.scroll(100)
pag.scroll(100)
pag.scroll(100)
pag.scroll(100)
pag.scroll(100)
#confirmar
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/span[2]/div[1]/div/div/div/div/div/span/div[1]/div/div[2]/span/div/div/span').click()
#confirmar criação de grupo
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[1]/span/div[1]/span/div[1]/div/span/div/div/span').click()
tm.sleep(3)
#mudar descrição do grupo
navegador.find_element_by_xpath('//*[@id="main"]/header').click()
tm.sleep(1)
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/div/section/div[2]/div[2]/div/div/span[2]/div/span').click()
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/div/section/div[2]/div[2]/div/div[1]/div/div[2]').send_keys('ESTE GRUPO FOI CRIADO COM O OBJETIVO DE FAZER UM TESTE DE AUTOMOÇÃO!!!')
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/div/section/div[2]/div[2]/div/div[1]/span[2]/div/span').click()
#entrar nas configurações de grupo
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/div/section/div[4]/div[4]/div/div[1]/span').click()
#editar dados do grupo
tm.sleep(1)
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/div/div[1]/div/div/div/div[1]/span').click()
tm.sleep(1)
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/span[2]/div[1]/div/div/div/div/div/div[2]/form/ol/li[2]/label/input').click()
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/span[2]/div[1]/div/div/div/div/div/div[3]/div[2]/div/div').click()
#enviar mensagens
tm.sleep(1)
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/div/div[3]/div/div/div/div[1]/span').click()
tm.sleep(1)
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/span[2]/div[1]/div/div/div/div/div/div[2]/form/ol/li[2]/label/input').click()
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/span[2]/div[1]/div/div/div/div/div/div[3]/div[2]/div/div').click()
#permitir outro admin
tm.sleep(1)
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/div/div[4]/div/div/div/div/span').click()
tm.sleep(1)
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/span[2]/div[1]/div/div/div/div/div/div/div[2]/div[1]/div/div/div[2]/div/div[2]/div/div[2]/div[1]/div/span/span').click()
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/span[2]/div[1]/div/div/div/div/div/div/span[2]/div/div/div/span').click()
#copiar convite via link
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/header/div/div[1]/button/span').click()
tm.sleep(1)
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/div/section/div[5]/div[3]/div[2]/div/div').click()
tm.sleep(1)
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/div/div[4]/div[2]/div/span').click()

#grupo 3
tm.sleep(3)
navegador.find_element_by_xpath('//*[@id="side"]/header/div[2]/div/span/div[3]/div/span').click()
navegador.find_element_by_xpath('//*[@id="side"]/header/div[2]/div/span/div[3]/span/div[1]/ul/li[1]/div[1]').click()
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[1]/span/div[1]/span/div[1]/div/div[1]/div/div/input').send_keys("meu amor")
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[1]/span/div[1]/span/div[1]/div/div[2]/div[1]/div/div/div/div/div/div[2]').click()
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[1]/span/div[1]/span/div[1]/div/span/div/span').click()
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[1]/span/div[1]/span/div[1]/div/div[2]/div/div[2]/div/div[2]').send_keys('TESTE DE AUTOMAÇÃO')
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[1]/span/div[1]/span/div[1]/div/div[1]/div/div/span/div/div[1]/span').click()
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/span[4]/div/ul/div/li[2]/div[1]').click()
tm.sleep(3)
pag.click(356,49)
tm.sleep(1)
pag.write(r'C:\Users\gabri\OneDrive\Imagens\Screenshots')
pag.press('enter')
tm.sleep(2)
pag.click(244,177, clicks=2)
tm.sleep(3)
pag.dragTo(660,389)
pag.scroll(100)
pag.scroll(100)
pag.scroll(100)
pag.scroll(100)
pag.scroll(100)
pag.scroll(100)
#confirmar
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/span[2]/div[1]/div/div/div/div/div/span/div[1]/div/div[2]/span/div/div/span').click()
#confirmar criação de grupo
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[1]/span/div[1]/span/div[1]/div/span/div/div/span').click()
tm.sleep(3)
#mudar descrição do grupo
navegador.find_element_by_xpath('//*[@id="main"]/header').click()
tm.sleep(1)
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/div/section/div[2]/div[2]/div/div/span[2]/div/span').click()
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/div/section/div[2]/div[2]/div/div[1]/div/div[2]').send_keys('ESTE GRUPO FOI CRIADO COM O OBJETIVO DE FAZER UM TESTE DE AUTOMOÇÃO!!!')
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/div/section/div[2]/div[2]/div/div[1]/span[2]/div/span').click()
#entrar nas configurações de grupo
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/div/section/div[4]/div[4]/div/div[1]/span').click()
#editar dados do grupo
tm.sleep(1)
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/div/div[1]/div/div/div/div[1]/span').click()
tm.sleep(1)
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/span[2]/div[1]/div/div/div/div/div/div[2]/form/ol/li[2]/label/input').click()
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/span[2]/div[1]/div/div/div/div/div/div[3]/div[2]/div/div').click()
#enviar mensagens
tm.sleep(1)
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/div/div[3]/div/div/div/div[1]/span').click()
tm.sleep(1)
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/span[2]/div[1]/div/div/div/div/div/div[2]/form/ol/li[2]/label/input').click()
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/span[2]/div[1]/div/div/div/div/div/div[3]/div[2]/div/div').click()
#permitir outro admin
tm.sleep(1)
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/div/div[4]/div/div/div/div/span').click()
tm.sleep(1)
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/span[2]/div[1]/div/div/div/div/div/div/div[2]/div[1]/div/div/div[2]/div/div[2]/div/div[2]/div[1]/div/span/span').click()
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/span[2]/div[1]/div/div/div/div/div/div/span[2]/div/div/div/span').click()
#copiar convite via link
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/header/div/div[1]/button/span').click()
tm.sleep(1)
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/div/section/div[5]/div[3]/div[2]/div/div').click()
tm.sleep(1)
navegador.find_element_by_xpath('//*[@id="app"]/div[1]/div[1]/div[2]/div[3]/span/div[1]/span/div[1]/div/div[4]/div[2]/div/span').click()
#navegador.find_element_by_xpath

# %%
##pag.position()

# %%
#tm.sleep(1)
#pag.dragTo(367,345)
#pag.scroll(100)
